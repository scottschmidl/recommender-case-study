# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
sys.path.append('../src/')

from anna_code import merge_dataframes

plt.style.use('bmh')

# %%
ratings_df = pd.read_csv('../data/ml-latest-small/ratings.csv')
movies_df = pd.read_csv('../data/ml-latest-small/movies.csv')
tags_df = pd.read_csv('../data/ml-latest-small/tags.csv')
links_df = pd.read_csv('../data/ml-latest-small/links.csv')
df = merge_dataframes(ratings_df, movies_df)

# %%
def to_year(title):
    str_year = title.strip()[-5:-1]
    if not str.isnumeric(str_year):
        return -1
    return int(str_year)

df['year'] = df['title'].apply(to_year)
df
# Out:
#         userId  movieId  rating   timestamp                           title  \
# 0            1        1     4.0   964982703                Toy Story (1995)
# 1            1        3     4.0   964981247         Grumpier Old Men (1995)
# 2            1        6     4.0   964982224                     Heat (1995)
# 3            1       47     5.0   964983815     Seven (a.k.a. Se7en) (1995)
# 4            1       50     5.0   964982931      Usual Suspects, The (1995)
# ...        ...      ...     ...         ...                             ...
# 100831     610   166534     4.0  1493848402                    Split (2017)
# 100832     610   168248     5.0  1493850091   John Wick: Chapter Two (2017)
# 100833     610   168250     5.0  1494273047                  Get Out (2017)
# 100834     610   168252     5.0  1493846352                    Logan (2017)
# 100835     610   170875     3.0  1493846415  The Fate of the Furious (2017)
#
#                                              genres  year
# 0       Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                                    Comedy|Romance  1995
# 2                             Action|Crime|Thriller  1995
# 3                                  Mystery|Thriller  1995
# 4                            Crime|Mystery|Thriller  1995
# ...                                             ...   ...
# 100831                        Drama|Horror|Thriller  2017
# 100832                        Action|Crime|Thriller  2017
# 100833                                       Horror  2017
# 100834                                Action|Sci-Fi  2017
# 100835                  Action|Crime|Drama|Thriller  2017
#
# [100836 rows x 7 columns]

# %%
def make_decades(df):
    df = df.copy()
    eighties = df[(df['year'] >= 1980) & (df['year'] < 1990)]
    ninties = df[(df['year'] >= 1990) & (df['year'] < 2000)]
    aughts = df[(df['year'] >= 2000) & (df['year'] < 2010)]
    tens = df[df['year'] >= 2010]
    return eighties, ninties, aughts, tens

# %%
def get_top_titles(df):
    df = df.copy()
    a = df.groupby('title')['rating'].value_counts().reset_index(name='rating_count')
    a = a[a['rating_count'] >=5]
    a.sort_values(by=['rating_count', 'rating'], ascending=False, inplace=True)[:10]
    return a

# %%
eighties, ninties, aughts, tens = make_decades(df)

# %%
top_eighties = get_top_titles(eighties)
top_eighties.head()
# Out:
#                                     title  rating  rating_count
# 17     1984 (Nineteen Eighty-Four) (1984)     4.0             5
# 23  2010: The Year We Make Contact (1984)     4.0             9
# 42    9 1/2 Weeks (Nine 1/2 Weeks) (1986)     3.0             6
# 48             About Last Night... (1986)     3.0             7
# 55                      Abyss, The (1989)     4.0            24

# %%
a.sort_values(by=['rating_count', 'rating'], ascending=False)[:10]
# Out:
#                                            title  rating  rating_count
# 23890           Shawshank Redemption, The (1994)     5.0           153
# 21516                        Pulp Fiction (1994)     5.0           123
# 9948                         Forrest Gump (1994)     5.0           116
# 17180                         Matrix, The (1999)     5.0           109
# 25347  Star Wars: Episode IV - A New Hope (1977)     5.0           104
# 14564                       Jurassic Park (1993)     4.0            97
# 24178           Silence of the Lambs, The (1991)     4.0            97
# 9949                         Forrest Gump (1994)     4.0            94
# 23318                    Schindler's List (1993)     5.0            92
# 24179           Silence of the Lambs, The (1991)     5.0            92

# %%
df.sort_values(by=['rating', 'timestamp'], ascending=False)
# Out:
#        userId  movieId  rating   timestamp  \
# 30174     210   177765     5.0  1537632257
# 46600     305   148671     5.0  1537354985
# 51318     331    57669     5.0  1537235356
# 51314     331    55820     5.0  1537235354
# 51202     331      608     5.0  1537235353
# ...       ...      ...     ...         ...
# 73897     474     2796     0.5  1053021959
# 74207     474     4040     0.5  1053021938
# 73540     474     1526     0.5  1053021910
# 74324     474     4676     0.5  1053021903
# 74494     474     5771     0.5  1053021898
#
#                                              title  \
# 30174                                  Coco (2017)
# 46600                                   Saw (2003)
# 51318                             In Bruges (2008)
# 51314                No Country for Old Men (2007)
# 51202                                 Fargo (1996)
# ...                                            ...
# 73897                            Funny Farm (1988)
# 74207  Don't Tell Mom the Babysitter's Dead (1991)
# 73540                          Fathers' Day (1997)
# 74324                   Troop Beverly Hills (1989)
# 74494                   My Bloody Valentine (1981)
#
#                              genres
# 30174  Adventure|Animation|Children
# 46600                  Crime|Horror
# 51318   Comedy|Crime|Drama|Thriller
# 51314                   Crime|Drama
# 51202   Comedy|Crime|Drama|Thriller
# ...                             ...
# 73897                        Comedy
# 74207                        Comedy
# 73540                        Comedy
# 74324                        Comedy
# 74494         Drama|Horror|Thriller
#
# [100836 rows x 6 columns]

# %%
fig, ax =
